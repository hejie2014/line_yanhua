# %% [markdown]
# Chapter 26
# # 可视化一元高斯分布概率密度函数
# Book_1《编程不难》 | 鸢尾花书：从加减乘除到机器学习

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from scipy.stats import norm #一元高斯函数

# %%
x_array = np.linspace(-6, 6, 200)
mu_array = np.linspace(-4, 4, 9)  #μ均值
# 设定均值一系列取值

# %%
mu_array
# Out:
# array([-4., -3., -2., -1.,  0.,  1.,  2.,  3.,  4.])

# %% [markdown]
# ##图像
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 中 np.linspace(0, 1, len(mu_array)) 返回一个由 0 到 1 之间等间隔的数值构成的数
# 组，数组的长度与 mu_array 的长度相同。mu_array 是之前定义的不同的均值取值。这些 [0, 1]
# 之间的数用到颜色映射。

# %% [markdown]
# 则利用 scipy.stats.norm.pdf(x, loc, scale) 函数；其中，x 为需要计算概率密度
# 的数值，可以是一个数值或一个数组。loc 为正态分布的均值，loc 是 location 的简写。scale 代
# 表正态分布的标准差。

# %% [markdown]
# d
# 设定曲线图例的字符串。其中，'$\mu$ = '是一个字符串，表示希腊字母"μ"。
#
# e
# 用于在绘制的图表中添加图例，ncol 是一个整数参数，用于设置图例的列数。

# %%
colors = cm.RdYlBu(np.linspace(0,1,len(mu_array)))  # 颜色

# %%
# 均值对一元高斯分布PDF影响
fig, ax = plt.subplots(figsize = (5,4))
for idx, mu_idx in enumerate(mu_array):  #索引：数值
    pdf_idx = norm.pdf(x_array,scale = 1,loc = mu_idx) #标准差不变；  μ 改变
    legend_idx = '$\mu$ = ' + str(mu_idx)
    plt.plot(x_array, pdf_idx,  # x，y
             color=colors[idx], # 颜色数组
             label = legend_idx) #标签

plt.legend(ncol=3) #ncol 是一个整数参数，用于设置图例的列数。
ax.set_xlim(x_array.min(),x_array.max()) #范围
ax.set_ylim(0,1)
ax.set_xlabel('x')  #标签
ax.set_ylabel('PDF, $f_X(x)$')
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\m'
# <>:5: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_4026/1251504110.py:5: SyntaxWarning: invalid escape sequence '\m'
#   legend_idx = '$\mu$ = ' + str(mu_idx)
# Text(0, 0.5, 'PDF, $f_X(x)$')

# %%
sigma_array = np.linspace(0.5,5,10) # 标准差
# 设定标准差一系列取值

# %%
colors = cm.RdYlBu(np.linspace(0,1,len(sigma_array))) #颜色

# %%
# 标准差对一元高斯分布PDF影响
fig, ax = plt.subplots(figsize = (5,4))
for idx, sigma_idx in enumerate(sigma_array):
    pdf_idx = norm.pdf(x_array, scale = sigma_idx) #标准差改变；  μ 不变
    legend_idx = '$\sigma$ = ' + str(sigma_idx)
    plt.plot(x_array, pdf_idx,
             color=colors[idx],
             label = legend_idx)

plt.legend()
ax.set_xlim(x_array.min(),x_array.max())
ax.set_ylim(0,1)
ax.set_xlabel('x')
ax.set_ylabel('PDF, $f_X(x)$')
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_4026/509376605.py:5: SyntaxWarning: invalid escape sequence '\s'
#   legend_idx = '$\sigma$ = ' + str(sigma_idx)
# Text(0, 0.5, 'PDF, $f_X(x)$')
