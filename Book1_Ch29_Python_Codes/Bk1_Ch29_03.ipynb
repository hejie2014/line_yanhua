# %% [markdown]
# Chapter 29
# # 标准化完成特征缩放
# Book_1《编程不难》 | 鸢尾花书：从加减乘除到机器学习

# %% [markdown]
# 特征缩放 (feature scaling) 是机器学习中的预处理步骤之一，用于调整数据中特征的范
# 围，使其更适合模型的训练。在许多机器学习算法中，特征的尺度差异可能导致模型表现不佳，因为某
# 些特征的值范围较大，而其他特征的值范围较小。
#
#
# 例如，如果一个特征的值范围在 0 到 1 之间，而另一个特征的值范围在-100 到 100 之间，模型可
# 能更关注值范围较大的特征，而对值范围较小的特征忽视。特征缩放的目的是消除这种差异，确保所有
# 特征对模型的影响相对均衡。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 导入包
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

# %%
# 使用load_iris()函数加载数据集
iris = load_iris()
X = iris.data    # 特征矩阵
y = iris.target  # 标签数组

# %% [markdown]
# #原始数据散点图

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 原始数据散点图
fig, ax = plt.subplots()
# 第一二列数据； s:点的大小； c：颜色（种类；标签）
ax.scatter(X[:, 0], X[:, 1], s = 18, c = y)

# 质心位置
# 每一列数据的均值
ax.axvline(x = X[:, 0].mean(), c = 'r')
ax.axhline(y = X[:, 1].mean(), c = 'r')
# 坐标轴
ax.axvline(x = 0, c = 'k')
ax.axhline(y = 0, c = 'k')
# 标签
ax.set_xlabel('Sepal length, cm')
ax.set_ylabel('Sepal width, cm')
ax.grid(True) # 显示网格
ax.set_aspect('equal', adjustable='box') # 等比例
ax.set_xbound(lower = -3, upper = 8) # 约束
ax.set_ybound(lower = -3, upper = 8)

# %% [markdown]
# 从 sklearn.preprocessing 库导入 StandardScaler，即标准化函数。
#
# 创建了一个 StandardScaler 的实例，命名为 scaler，这个实例将被用于对数据进行标准化
# 处理。
#
# 使用 StandardScaler 的 fit_transform 方法，将特征矩阵进行标准化处理，并将结果保
# 存在 X_z_score 中。

# %% [markdown]
# ##标准化特征数据矩阵

# %%
from sklearn.preprocessing import StandardScaler
# 标准化特征数据矩阵
scaler = StandardScaler()
X_z_score = scaler.fit_transform(X)

# %%
scaler
# Out:
# StandardScaler()

# %%
type(scaler)
# Out:
# sklearn.preprocessing._data.StandardScaler

# %%
X_z_score.shape  # 标准化的数据
# Out:
# (150, 4)

# %% [markdown]
# #标准化数据散点图

# %% [markdown]
# 注意质心的位置为（0,0）

# %%
# 标准化数据散点图

# X_z_score是标准化的数据
fig, ax = plt.subplots()
ax.scatter(X_z_score[:, 0], X_z_score[:, 1], s = 18, c = y)
# 质心位置
ax.axvline(x = X_z_score[:, 0].mean(), c = 'r')
ax.axhline(y = X_z_score[:, 1].mean(), c = 'r')
ax.set_xlabel('Sepal length, z-score')
ax.set_ylabel('Sepal width, z-score')
ax.grid(True)
ax.set_aspect('equal', adjustable='box')
ax.set_xbound(lower = -3, upper = 8)
ax.set_ybound(lower = -3, upper = 8)
