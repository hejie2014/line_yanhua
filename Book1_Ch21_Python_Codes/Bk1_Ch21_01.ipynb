# %% [markdown]
# Chapter 21
# # Pandas数据帧索引和切片
# Book_1《编程不难》 | 鸢尾花书：从加减乘除到机器学习

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 导入数据

# %%
iris_df_original = sns.load_dataset("iris")
# 从Seaborn中导入鸢尾花数据帧

# %%
iris_df_original.columns #获取列标签
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris_df = iris_df_original.copy()
iris_df = iris_df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
iris_df = iris_df.rename(columns={'sepal_length': 'X1',
                                  'sepal_width':  'X2',
                                  'petal_length': 'X3',
                                  'petal_width':  'X4'})
iris_df
# Out:
#       X1   X2   X3   X4
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# ..   ...  ...  ...  ...
# 145  6.7  3.0  5.2  2.3
# 146  6.3  2.5  5.0  1.9
# 147  6.5  3.0  5.2  2.0
# 148  6.2  3.4  5.4  2.3
# 149  5.9  3.0  5.1  1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# ## 提取列

# %% [markdown]
# ### 取出某一列

# %% [markdown]
# #### 结果为数据帧

# %%
iris_df[['X1']] #还是数据帧（花式索引）
# Out:
#       X1
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# ..   ...
# 145  6.7
# 146  6.3
# 147  6.5
# 148  6.2
# 149  5.9
#
# [150 rows x 1 columns]

# %%
iris_df.loc[:,['X1']]  # loc
# Out:
#       X1
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# ..   ...
# 145  6.7
# 146  6.3
# 147  6.5
# 148  6.2
# 149  5.9
#
# [150 rows x 1 columns]

# %%
iris_df.iloc[:,[0]]
# Out:
#       X1
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# ..   ...
# 145  6.7
# 146  6.3
# 147  6.5
# 148  6.2
# 149  5.9
#
# [150 rows x 1 columns]

# %%
iris_df.columns
# Out:
# Index(['X1', 'X2', 'X3', 'X4'], dtype='object')

# %%
iris_df.columns == 'X1'
# Out:
# array([ True, False, False, False])

# %% [markdown]
# #### 结果为Series

# %%
iris_df.loc[:,'X1'] #结果为Series
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: X1, Length: 150, dtype: float64

# %%
iris_df['X1']
# 结果为Pandas series
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: X1, Length: 150, dtype: float64

# %%
iris_df.X1
# 结果为Pandas series
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: X1, Length: 150, dtype: float64

# %%
iris_df.iloc[:,0]
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: X1, Length: 150, dtype: float64

# %% [markdown]
# ### 提取多列

# %% [markdown]
# #### 连续

# %%
iris_df[['X1', 'X2', 'X3']]
# Out:
#       X1   X2   X3
# 0    5.1  3.5  1.4
# 1    4.9  3.0  1.4
# 2    4.7  3.2  1.3
# 3    4.6  3.1  1.5
# 4    5.0  3.6  1.4
# ..   ...  ...  ...
# 145  6.7  3.0  5.2
# 146  6.3  2.5  5.0
# 147  6.5  3.0  5.2
# 148  6.2  3.4  5.4
# 149  5.9  3.0  5.1
#
# [150 rows x 3 columns]

# %%
iris_df.loc[:,['X1','X2','X3']]
# Out:
#       X1   X2   X3
# 0    5.1  3.5  1.4
# 1    4.9  3.0  1.4
# 2    4.7  3.2  1.3
# 3    4.6  3.1  1.5
# 4    5.0  3.6  1.4
# ..   ...  ...  ...
# 145  6.7  3.0  5.2
# 146  6.3  2.5  5.0
# 147  6.5  3.0  5.2
# 148  6.2  3.4  5.4
# 149  5.9  3.0  5.1
#
# [150 rows x 3 columns]

# %%
iris_df.iloc[:,0:3]
# Out:
#       X1   X2   X3
# 0    5.1  3.5  1.4
# 1    4.9  3.0  1.4
# 2    4.7  3.2  1.3
# 3    4.6  3.1  1.5
# 4    5.0  3.6  1.4
# ..   ...  ...  ...
# 145  6.7  3.0  5.2
# 146  6.3  2.5  5.0
# 147  6.5  3.0  5.2
# 148  6.2  3.4  5.4
# 149  5.9  3.0  5.1
#
# [150 rows x 3 columns]

# %%
iris_df.iloc[:,:3]
# Out:
#       X1   X2   X3
# 0    5.1  3.5  1.4
# 1    4.9  3.0  1.4
# 2    4.7  3.2  1.3
# 3    4.6  3.1  1.5
# 4    5.0  3.6  1.4
# ..   ...  ...  ...
# 145  6.7  3.0  5.2
# 146  6.3  2.5  5.0
# 147  6.5  3.0  5.2
# 148  6.2  3.4  5.4
# 149  5.9  3.0  5.1
#
# [150 rows x 3 columns]

# %% [markdown]
# #### 不连续

# %%
iris_df[['X1', 'X4']]
# Out:
#       X1   X4
# 0    5.1  0.2
# 1    4.9  0.2
# 2    4.7  0.2
# 3    4.6  0.2
# 4    5.0  0.2
# ..   ...  ...
# 145  6.7  2.3
# 146  6.3  1.9
# 147  6.5  2.0
# 148  6.2  2.3
# 149  5.9  1.8
#
# [150 rows x 2 columns]

# %%
iris_df.loc[:,['X1', 'X4']]
# Out:
#       X1   X4
# 0    5.1  0.2
# 1    4.9  0.2
# 2    4.7  0.2
# 3    4.6  0.2
# 4    5.0  0.2
# ..   ...  ...
# 145  6.7  2.3
# 146  6.3  1.9
# 147  6.5  2.0
# 148  6.2  2.3
# 149  5.9  1.8
#
# [150 rows x 2 columns]

# %%
iris_df.iloc[:,[0, 3]] #[0, 3]
# Out:
#       X1   X4
# 0    5.1  0.2
# 1    4.9  0.2
# 2    4.7  0.2
# 3    4.6  0.2
# 4    5.0  0.2
# ..   ...  ...
# 145  6.7  2.3
# 146  6.3  1.9
# 147  6.5  2.0
# 148  6.2  2.3
# 149  5.9  1.8
#
# [150 rows x 2 columns]

# %% [markdown]
# 为什么会报错？
# iris_df['X1', 'X2'] 这种写法，Pandas 会把它理解为：同时选择列 'X1' 和 'X2'，但这个语法是错误的。
#
# 错误原因
# 'X1', 'X2' 在 Python 中会被解释为一个元组 (tuple)：('X1', 'X2')
#
# 当你写 df[('X1', 'X2')] 时，Pandas 会去查找列名为 ('X1', 'X2') 的列
#
# 如果你的 DataFrame 没有列名是元组，就会报错 KeyError

# %%
iris_df['X1', 'X2'] #  标签不对
# 会报错 KeyError

# %%
# 等间隔
iris_df.iloc[:,::2] # step步长
# Out:
#       X1   X3
# 0    5.1  1.4
# 1    4.9  1.4
# 2    4.7  1.3
# 3    4.6  1.5
# 4    5.0  1.4
# ..   ...  ...
# 145  6.7  5.2
# 146  6.3  5.0
# 147  6.5  5.2
# 148  6.2  5.4
# 149  5.9  5.1
#
# [150 rows x 2 columns]

# %% [markdown]
# ## 提取行

# %% [markdown]
# ### 提取某一行

# %%
iris_df_ = iris_df.rename(lambda x: f'idx_{x}')  #默认行标签
iris_df_
# Out:
#           X1   X2   X3   X4
# idx_0    5.1  3.5  1.4  0.2
# idx_1    4.9  3.0  1.4  0.2
# idx_2    4.7  3.2  1.3  0.2
# idx_3    4.6  3.1  1.5  0.2
# idx_4    5.0  3.6  1.4  0.2
# ...      ...  ...  ...  ...
# idx_145  6.7  3.0  5.2  2.3
# idx_146  6.3  2.5  5.0  1.9
# idx_147  6.5  3.0  5.2  2.0
# idx_148  6.2  3.4  5.4  2.3
# idx_149  5.9  3.0  5.1  1.8
#
# [150 rows x 4 columns]

# %%
iris_df_.loc['idx_0']
# Out:
# X1    5.1
# X2    3.5
# X3    1.4
# X4    0.2
# Name: idx_0, dtype: float64

# %%
iris_df_.iloc[0]
# Out:
# X1    5.1
# X2    3.5
# X3    1.4
# X4    0.2
# Name: idx_0, dtype: float64

# %%
type(iris_df_.iloc[0])
# Out:
# pandas.core.series.Series

# %%
iris_df_.iloc[[0]]
# Out:
#         X1   X2   X3   X4
# idx_0  5.1  3.5  1.4  0.2

# %%
iris_df_.loc[['idx_0']]
# Out:
#         X1   X2   X3   X4
# idx_0  5.1  3.5  1.4  0.2

# %%
# 行非默认标签

# %%
# 布尔索引
condition = (iris_df.index == 1)
iris_df[condition]
# Out:
#     X1   X2   X3   X4
# 1  4.9  3.0  1.4  0.2

# %%
iris_df

# %% [markdown]
# ### 提取几行

# %% [markdown]
# #### 连续

# %%
iris_df_.iloc[[0,1,2]]
# Out:
#         X1   X2   X3   X4
# idx_0  5.1  3.5  1.4  0.2
# idx_1  4.9  3.0  1.4  0.2
# idx_2  4.7  3.2  1.3  0.2

# %%
iris_df_.iloc[0:3]
# 不包含整数位置索引3，只选取位置0、1、2的行
# Out:
#         X1   X2   X3   X4
# idx_0  5.1  3.5  1.4  0.2
# idx_1  4.9  3.0  1.4  0.2
# idx_2  4.7  3.2  1.3  0.2

# %%
iris_df_.iloc[:3]
# 不包含整数位置索引3，只选取位置0、1、2的行
# Out:
#         X1   X2   X3   X4
# idx_0  5.1  3.5  1.4  0.2
# idx_1  4.9  3.0  1.4  0.2
# idx_2  4.7  3.2  1.3  0.2

# %%
iris_df_.loc[['idx_0', 'idx_1', 'idx_2']]
# Out:
#         X1   X2   X3   X4
# idx_0  5.1  3.5  1.4  0.2
# idx_1  4.9  3.0  1.4  0.2
# idx_2  4.7  3.2  1.3  0.2

# %% [markdown]
# #### 不连续

# %%
iris_df_.iloc[[0,50,100]]
# Out:
#           X1   X2   X3   X4
# idx_0    5.1  3.5  1.4  0.2
# idx_50   7.0  3.2  4.7  1.4
# idx_100  6.3  3.3  6.0  2.5

# %%
iris_df_.loc[['idx_0','idx_50','idx_100']]
# Out:
#           X1   X2   X3   X4
# idx_0    5.1  3.5  1.4  0.2
# idx_50   7.0  3.2  4.7  1.4
# idx_100  6.3  3.3  6.0  2.5

# %% [markdown]
# ## 提取元素

# %% [markdown]
# ### 某一元素

# %%
iris_df.iloc[::10,[0]]
# Out:
#       X1
# 0    5.1
# 10   5.4
# 20   5.4
# 30   4.8
# 40   5.0
# 50   7.0
# 60   5.0
# 70   5.9
# 80   5.5
# 90   5.5
# 100  6.3
# 110  6.5
# 120  6.9
# 130  7.4
# 140  6.7

# %%
iris_df.iloc[1:5, 2:4]
# Out:
#     X3   X4
# 1  1.4  0.2
# 2  1.3  0.2
# 3  1.5  0.2
# 4  1.4  0.2

# %%
iris_df.iloc[[1, 3, 5], [1, 3]]
# Out:
#     X2   X4
# 1  3.0  0.2
# 3  3.1  0.2
# 5  3.9  0.4

# %%
iris_df.iloc[1:3, :]
# Out:
#     X1   X2   X3   X4
# 1  4.9  3.0  1.4  0.2
# 2  4.7  3.2  1.3  0.2

# %%
iris_df.iloc[:, 1:3]
# Out:
#       X2   X3
# 0    3.5  1.4
# 1    3.0  1.4
# 2    3.2  1.3
# 3    3.1  1.5
# 4    3.6  1.4
# ..   ...  ...
# 145  3.0  5.2
# 146  2.5  5.0
# 147  3.0  5.2
# 148  3.4  5.4
# 149  3.0  5.1
#
# [150 rows x 2 columns]

# %%
iris_df.iloc[1,1] #坐标为1,1的数据
# Out:
# np.float64(3.0)

# %% [markdown]
# ### 使用at、iat

# %%
iris_df_.head()
# Out:
#         X1   X2   X3   X4
# idx_0  5.1  3.5  1.4  0.2
# idx_1  4.9  3.0  1.4  0.2
# idx_2  4.7  3.2  1.3  0.2
# idx_3  4.6  3.1  1.5  0.2
# idx_4  5.0  3.6  1.4  0.2

# %%
iris_df_.at['idx_0', 'X1']
# Out:
# np.float64(5.1)

# %%
iris_df_.iat[0, 0] # 整数索引
# Out:
# np.float64(5.1)

# %%
iris_df_.loc['idx_0', 'X1']
# Out:
# np.float64(5.1)

# %%
iris_df_.iloc[0,0]
# Out:
# np.float64(5.1)

# %%
iris_df_.iloc[[0],[0]]
# Out:
#         X1
# idx_0  5.1

# %%
iris_df_.loc[['idx_0'], ['X1']]
# Out:
#         X1
# idx_0  5.1

# %% [markdown]
# ## 条件索引

# %% [markdown]
# ### 布尔条件

# %%
Boolean_df = (iris_df > 6) | (iris_df < 1.5)
Boolean_df
# Out:
#         X1     X2     X3     X4
# 0    False  False   True   True
# 1    False  False   True   True
# 2    False  False   True   True
# 3    False  False  False   True
# 4    False  False   True   True
# ..     ...    ...    ...    ...
# 145   True  False  False  False
# 146   True  False  False  False
# 147   True  False  False  False
# 148   True  False  False  False
# 149  False  False  False  False
#
# [150 rows x 4 columns]

# %%
fig,ax = plt.subplots(figsize = (3,5))
sns.heatmap(Boolean_df,
            cmap = 'Blues',
            ax = ax,
            cbar=False,
            xticklabels = [],
            yticklabels = [],
            cbar_kws = {'orientation':'vertical'},
            annot=False)

fig.savefig('鸢尾花数据dataframe_布尔条件.svg', format='svg')

# %%
condition = iris_df['X1'] >= 7
iris_df[condition]
# 取出满足条件的行
# Out:
#       X1   X2   X3   X4
# 50   7.0  3.2  4.7  1.4
# 102  7.1  3.0  5.9  2.1
# 105  7.6  3.0  6.6  2.1
# 107  7.3  2.9  6.3  1.8
# 109  7.2  3.6  6.1  2.5
# 117  7.7  3.8  6.7  2.2
# 118  7.7  2.6  6.9  2.3
# 122  7.7  2.8  6.7  2.0
# 125  7.2  3.2  6.0  1.8
# 129  7.2  3.0  5.8  1.6
# 130  7.4  2.8  6.1  1.9
# 131  7.9  3.8  6.4  2.0
# 135  7.7  3.0  6.1  2.3

# %%
iris_df[condition].shape
# Out:
# (13, 4)

# %%
fig,ax = plt.subplots(figsize = (6,8))
sns.heatmap(iris_df[condition],
            cmap = 'RdYlBu_r',
            ax = ax,
            vmax = 0, vmin = 8,
            cbar_kws = {'orientation':'vertical'},
            annot=False)

fig.savefig('鸢尾花数据dataframe_满足条件的行.svg', format='svg')

# %%
iris_df.loc[:,'X1'] >= 7
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: X1, Length: 150, dtype: bool

# %%
iris_df.loc[iris_df.loc[:,'X1'] >= 7, :] #选取x1大于7的行
# Out:
#       X1   X2   X3   X4
# 50   7.0  3.2  4.7  1.4
# 102  7.1  3.0  5.9  2.1
# 105  7.6  3.0  6.6  2.1
# 107  7.3  2.9  6.3  1.8
# 109  7.2  3.6  6.1  2.5
# 117  7.7  3.8  6.7  2.2
# 118  7.7  2.6  6.9  2.3
# 122  7.7  2.8  6.7  2.0
# 125  7.2  3.2  6.0  1.8
# 129  7.2  3.0  5.8  1.6
# 130  7.4  2.8  6.1  1.9
# 131  7.9  3.8  6.4  2.0
# 135  7.7  3.0  6.1  2.3

# %%
iris_df_original.loc[iris_df_original.loc[:,'species'] == 'versicolor', :]

# %%
iris_df_original.loc[iris_df_original.species == 'versicolor', :]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# 55           5.7          2.8           4.5          1.3  versicolor
# 56           6.3          3.3           4.7          1.6  versicolor
# 57           4.9          2.4           3.3          1.0  versicolor
# 58           6.6          2.9           4.6          1.3  versicolor
# 59           5.2          2.7           3.9          1.4  versicolor
# 60           5.0          2.0           3.5          1.0  versicolor
# 61           5.9          3.0           4.2          1.5  versicolor
# 62           6.0          2.2           4.0          1.0  versicolor
# 63           6.1          2.9           4.7          1.4  versicolor
# 64           5.6          2.9           3.6          1.3  versicolor
# 65           6.7          3.1           4.4          1.4  versicolor
# 66           5.6          3.0           4.5          1.5  versicolor
# 67           5.8          2.7           4.1          1.0  versicolor
# 68           6.2          2.2           4.5          1.5  versicolor
# 69           5.6          2.5           3.9          1.1  versicolor
# 70           5.9          3.2           4.8          1.8  versicolor
# 71           6.1          2.8           4.0          1.3  versicolor
# 72           6.3          2.5           4.9          1.5  versicolor
# 73           6.1          2.8           4.7          1.2  versicolor
# 74           6.4          2.9           4.3          1.3  versicolor
# 75           6.6          3.0           4.4          1.4  versicolor
# 76           6.8          2.8           4.8          1.4  versicolor
# 77           6.7          3.0           5.0          1.7  versicolor
# 78           6.0          2.9           4.5          1.5  versicolor
# 79           5.7          2.6           3.5          1.0  versicolor
# 80           5.5          2.4           3.8          1.1  versicolor
# 81           5.5          2.4           3.7          1.0  versicolor
# 82           5.8          2.7           3.9          1.2  versicolor
# 83           6.0          2.7           5.1          1.6  versicolor
# 84           5.4          3.0           4.5          1.5  versicolor
# 85           6.0          3.4           4.5          1.6  versicolor
# 86           6.7          3.1           4.7          1.5  versicolor
# 87           6.3          2.3           4.4          1.3  versicolor
# 88           5.6          3.0           4.1          1.3  versicolor
# 89           5.5          2.5           4.0          1.3  versicolor
# 90           5.5          2.6           4.4          1.2  versicolor
# 91           6.1          3.0           4.6          1.4  versicolor
# 92           5.8          2.6           4.0          1.2  versicolor
# 93           5.0          2.3           3.3          1.0  versicolor
# 94           5.6          2.7           4.2          1.3  versicolor
# 95           5.7          3.0           4.2          1.2  versicolor
# 96           5.7          2.9           4.2          1.3  versicolor
# 97           6.2          2.9           4.3          1.3  versicolor
# 98           5.1          2.5           3.0          1.1  versicolor
# 99           5.7          2.8           4.1          1.3  versicolor

# %%
iris_df_original.loc[(iris_df_original.sepal_length < 6.5) &
                     (iris_df_original.sepal_length > 6)]
# 或，非
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 51            6.4          3.2           4.5          1.5  versicolor
# 56            6.3          3.3           4.7          1.6  versicolor
# 63            6.1          2.9           4.7          1.4  versicolor
# 68            6.2          2.2           4.5          1.5  versicolor
# 71            6.1          2.8           4.0          1.3  versicolor
# 72            6.3          2.5           4.9          1.5  versicolor
# 73            6.1          2.8           4.7          1.2  versicolor
# 74            6.4          2.9           4.3          1.3  versicolor
# 87            6.3          2.3           4.4          1.3  versicolor
# 91            6.1          3.0           4.6          1.4  versicolor
# 97            6.2          2.9           4.3          1.3  versicolor
# 100           6.3          3.3           6.0          2.5   virginica
# 103           6.3          2.9           5.6          1.8   virginica
# 111           6.4          2.7           5.3          1.9   virginica
# 115           6.4          3.2           5.3          2.3   virginica
# 123           6.3          2.7           4.9          1.8   virginica
# 126           6.2          2.8           4.8          1.8   virginica
# 127           6.1          3.0           4.9          1.8   virginica
# 128           6.4          2.8           5.6          2.1   virginica
# 132           6.4          2.8           5.6          2.2   virginica
# 133           6.3          2.8           5.1          1.5   virginica
# 134           6.1          2.6           5.6          1.4   virginica
# 136           6.3          3.4           5.6          2.4   virginica
# 137           6.4          3.1           5.5          1.8   virginica
# 146           6.3          2.5           5.0          1.9   virginica
# 148           6.2          3.4           5.4          2.3   virginica

# %%
iris_df_original.loc[(iris_df_original.sepal_length < 6.5) &
                     (iris_df_original.sepal_length > 6),
                     ['petal_length', 'petal_width']]
# Out:
#      petal_length  petal_width
# 51            4.5          1.5
# 56            4.7          1.6
# 63            4.7          1.4
# 68            4.5          1.5
# 71            4.0          1.3
# 72            4.9          1.5
# 73            4.7          1.2
# 74            4.3          1.3
# 87            4.4          1.3
# 91            4.6          1.4
# 97            4.3          1.3
# 100           6.0          2.5
# 103           5.6          1.8
# 111           5.3          1.9
# 115           5.3          2.3
# 123           4.9          1.8
# 126           4.8          1.8
# 127           4.9          1.8
# 128           5.6          2.1
# 132           5.6          2.2
# 133           5.1          1.5
# 134           5.6          1.4
# 136           5.6          2.4
# 137           5.5          1.8
# 146           5.0          1.9
# 148           5.4          2.3

# %%
iris_df_original.loc[iris_df_original['species'] != 'virginica']
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 0            5.1          3.5           1.4          0.2      setosa
# 1            4.9          3.0           1.4          0.2      setosa
# 2            4.7          3.2           1.3          0.2      setosa
# 3            4.6          3.1           1.5          0.2      setosa
# 4            5.0          3.6           1.4          0.2      setosa
# ..           ...          ...           ...          ...         ...
# 95           5.7          3.0           4.2          1.2  versicolor
# 96           5.7          2.9           4.2          1.3  versicolor
# 97           6.2          2.9           4.3          1.3  versicolor
# 98           5.1          2.5           3.0          1.1  versicolor
# 99           5.7          2.8           4.1          1.3  versicolor
#
# [100 rows x 5 columns]

# %%
iris_df_original.loc[iris_df_original['species'].isin(['virginica','setosa'])]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [100 rows x 5 columns]

# %%
iris_df_original.loc[~iris_df_original['species'].isin(['virginica','setosa']),
                    ['petal_length', 'petal_width']]
# Out:
#     petal_length  petal_width
# 50           4.7          1.4
# 51           4.5          1.5
# 52           4.9          1.5
# 53           4.0          1.3
# 54           4.6          1.5
# 55           4.5          1.3
# 56           4.7          1.6
# 57           3.3          1.0
# 58           4.6          1.3
# 59           3.9          1.4
# 60           3.5          1.0
# 61           4.2          1.5
# 62           4.0          1.0
# 63           4.7          1.4
# 64           3.6          1.3
# 65           4.4          1.4
# 66           4.5          1.5
# 67           4.1          1.0
# 68           4.5          1.5
# 69           3.9          1.1
# 70           4.8          1.8
# 71           4.0          1.3
# 72           4.9          1.5
# 73           4.7          1.2
# 74           4.3          1.3
# 75           4.4          1.4
# 76           4.8          1.4
# 77           5.0          1.7
# 78           4.5          1.5
# 79           3.5          1.0
# 80           3.8          1.1
# 81           3.7          1.0
# 82           3.9          1.2
# 83           5.1          1.6
# 84           4.5          1.5
# 85           4.5          1.6
# 86           4.7          1.5
# 87           4.4          1.3
# 88           4.1          1.3
# 89           4.0          1.3
# 90           4.4          1.2
# 91           4.6          1.4
# 92           4.0          1.2
# 93           3.3          1.0
# 94           4.2          1.3
# 95           4.2          1.2
# 96           4.2          1.3
# 97           4.3          1.3
# 98           3.0          1.1
# 99           4.1          1.3

# %%
iris_df_original.loc[iris_df_original.species.isin(['setosa', 'virginica'])]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [100 rows x 5 columns]

# %% [markdown]
# ### query()

# %%
iris_df_original.query('sepal_length > 2*sepal_width')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 50            7.0          3.2           4.7          1.4  versicolor
# 52            6.9          3.1           4.9          1.5  versicolor
# 53            5.5          2.3           4.0          1.3  versicolor
# 54            6.5          2.8           4.6          1.5  versicolor
# 55            5.7          2.8           4.5          1.3  versicolor
# ..            ...          ...           ...          ...         ...
# 143           6.8          3.2           5.9          2.3   virginica
# 144           6.7          3.3           5.7          2.5   virginica
# 145           6.7          3.0           5.2          2.3   virginica
# 146           6.3          2.5           5.0          1.9   virginica
# 147           6.5          3.0           5.2          2.0   virginica
#
# [79 rows x 5 columns]

# %%
iris_df_original.query("petal_length + petal_width < sepal_length + sepal_width")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris_df_original.query("species == 'versicolor'")
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# 55           5.7          2.8           4.5          1.3  versicolor
# 56           6.3          3.3           4.7          1.6  versicolor
# 57           4.9          2.4           3.3          1.0  versicolor
# 58           6.6          2.9           4.6          1.3  versicolor
# 59           5.2          2.7           3.9          1.4  versicolor
# 60           5.0          2.0           3.5          1.0  versicolor
# 61           5.9          3.0           4.2          1.5  versicolor
# 62           6.0          2.2           4.0          1.0  versicolor
# 63           6.1          2.9           4.7          1.4  versicolor
# 64           5.6          2.9           3.6          1.3  versicolor
# 65           6.7          3.1           4.4          1.4  versicolor
# 66           5.6          3.0           4.5          1.5  versicolor
# 67           5.8          2.7           4.1          1.0  versicolor
# 68           6.2          2.2           4.5          1.5  versicolor
# 69           5.6          2.5           3.9          1.1  versicolor
# 70           5.9          3.2           4.8          1.8  versicolor
# 71           6.1          2.8           4.0          1.3  versicolor
# 72           6.3          2.5           4.9          1.5  versicolor
# 73           6.1          2.8           4.7          1.2  versicolor
# 74           6.4          2.9           4.3          1.3  versicolor
# 75           6.6          3.0           4.4          1.4  versicolor
# 76           6.8          2.8           4.8          1.4  versicolor
# 77           6.7          3.0           5.0          1.7  versicolor
# 78           6.0          2.9           4.5          1.5  versicolor
# 79           5.7          2.6           3.5          1.0  versicolor
# 80           5.5          2.4           3.8          1.1  versicolor
# 81           5.5          2.4           3.7          1.0  versicolor
# 82           5.8          2.7           3.9          1.2  versicolor
# 83           6.0          2.7           5.1          1.6  versicolor
# 84           5.4          3.0           4.5          1.5  versicolor
# 85           6.0          3.4           4.5          1.6  versicolor
# 86           6.7          3.1           4.7          1.5  versicolor
# 87           6.3          2.3           4.4          1.3  versicolor
# 88           5.6          3.0           4.1          1.3  versicolor
# 89           5.5          2.5           4.0          1.3  versicolor
# 90           5.5          2.6           4.4          1.2  versicolor
# 91           6.1          3.0           4.6          1.4  versicolor
# 92           5.8          2.6           4.0          1.2  versicolor
# 93           5.0          2.3           3.3          1.0  versicolor
# 94           5.6          2.7           4.2          1.3  versicolor
# 95           5.7          3.0           4.2          1.2  versicolor
# 96           5.7          2.9           4.2          1.3  versicolor
# 97           6.2          2.9           4.3          1.3  versicolor
# 98           5.1          2.5           3.0          1.1  versicolor
# 99           5.7          2.8           4.1          1.3  versicolor

# %%
iris_df_original.query("not (sepal_length > 7 and petal_width > 0.5)")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [138 rows x 5 columns]

# %%
iris_df_original.query("species != 'versicolor'")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [100 rows x 5 columns]

# %%
iris_df_original.query("abs(sepal_length-6) > 1")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 6             4.6          3.4           1.4          0.3      setosa
# 8             4.4          2.9           1.4          0.2      setosa
# 9             4.9          3.1           1.5          0.1      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# 12            4.8          3.0           1.4          0.1      setosa
# 13            4.3          3.0           1.1          0.1      setosa
# 22            4.6          3.6           1.0          0.2      setosa
# 24            4.8          3.4           1.9          0.2      setosa
# 29            4.7          3.2           1.6          0.2      setosa
# 30            4.8          3.1           1.6          0.2      setosa
# 34            4.9          3.1           1.5          0.2      setosa
# 37            4.9          3.6           1.4          0.1      setosa
# 38            4.4          3.0           1.3          0.2      setosa
# 41            4.5          2.3           1.3          0.3      setosa
# 42            4.4          3.2           1.3          0.2      setosa
# 45            4.8          3.0           1.4          0.3      setosa
# 47            4.6          3.2           1.4          0.2      setosa
# 57            4.9          2.4           3.3          1.0  versicolor
# 102           7.1          3.0           5.9          2.1   virginica
# 105           7.6          3.0           6.6          2.1   virginica
# 106           4.9          2.5           4.5          1.7   virginica
# 107           7.3          2.9           6.3          1.8   virginica
# 109           7.2          3.6           6.1          2.5   virginica
# 117           7.7          3.8           6.7          2.2   virginica
# 118           7.7          2.6           6.9          2.3   virginica
# 122           7.7          2.8           6.7          2.0   virginica
# 125           7.2          3.2           6.0          1.8   virginica
# 129           7.2          3.0           5.8          1.6   virginica
# 130           7.4          2.8           6.1          1.9   virginica
# 131           7.9          3.8           6.4          2.0   virginica
# 135           7.7          3.0           6.1          2.3   virginica

# %%
iris_df_original.query("species in ('versicolor','virginica')")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 50            7.0          3.2           4.7          1.4  versicolor
# 51            6.4          3.2           4.5          1.5  versicolor
# 52            6.9          3.1           4.9          1.5  versicolor
# 53            5.5          2.3           4.0          1.3  versicolor
# 54            6.5          2.8           4.6          1.5  versicolor
# ..            ...          ...           ...          ...         ...
# 145           6.7          3.0           5.2          2.3   virginica
# 146           6.3          2.5           5.0          1.9   virginica
# 147           6.5          3.0           5.2          2.0   virginica
# 148           6.2          3.4           5.4          2.3   virginica
# 149           5.9          3.0           5.1          1.8   virginica
#
# [100 rows x 5 columns]

# %%
iris_df_original.query("sepal_length >= 6.5 or sepal_length <= 4.5")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 8             4.4          2.9           1.4          0.2      setosa
# 13            4.3          3.0           1.1          0.1      setosa
# 38            4.4          3.0           1.3          0.2      setosa
# 41            4.5          2.3           1.3          0.3      setosa
# 42            4.4          3.2           1.3          0.2      setosa
# 50            7.0          3.2           4.7          1.4  versicolor
# 52            6.9          3.1           4.9          1.5  versicolor
# 54            6.5          2.8           4.6          1.5  versicolor
# 58            6.6          2.9           4.6          1.3  versicolor
# 65            6.7          3.1           4.4          1.4  versicolor
# 75            6.6          3.0           4.4          1.4  versicolor
# 76            6.8          2.8           4.8          1.4  versicolor
# 77            6.7          3.0           5.0          1.7  versicolor
# 86            6.7          3.1           4.7          1.5  versicolor
# 102           7.1          3.0           5.9          2.1   virginica
# 104           6.5          3.0           5.8          2.2   virginica
# 105           7.6          3.0           6.6          2.1   virginica
# 107           7.3          2.9           6.3          1.8   virginica
# 108           6.7          2.5           5.8          1.8   virginica
# 109           7.2          3.6           6.1          2.5   virginica
# 110           6.5          3.2           5.1          2.0   virginica
# 112           6.8          3.0           5.5          2.1   virginica
# 116           6.5          3.0           5.5          1.8   virginica
# 117           7.7          3.8           6.7          2.2   virginica
# 118           7.7          2.6           6.9          2.3   virginica
# 120           6.9          3.2           5.7          2.3   virginica
# 122           7.7          2.8           6.7          2.0   virginica
# 124           6.7          3.3           5.7          2.1   virginica
# 125           7.2          3.2           6.0          1.8   virginica
# 129           7.2          3.0           5.8          1.6   virginica
# 130           7.4          2.8           6.1          1.9   virginica
# 131           7.9          3.8           6.4          2.0   virginica
# 135           7.7          3.0           6.1          2.3   virginica
# 139           6.9          3.1           5.4          2.1   virginica
# 140           6.7          3.1           5.6          2.4   virginica
# 141           6.9          3.1           5.1          2.3   virginica
# 143           6.8          3.2           5.9          2.3   virginica
# 144           6.7          3.3           5.7          2.5   virginica
# 145           6.7          3.0           5.2          2.3   virginica
# 147           6.5          3.0           5.2          2.0   virginica

# %%
iris_df_original.query("sepal_length <= 6.5 and sepal_length >= 4.5")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 142           5.8          2.7           5.1          1.9  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [116 rows x 5 columns]

# %% [markdown]
# ## 多层索引

# %% [markdown]
# ### 多层行

# %%
import pandas as pd
import numpy as np
# 示例数据
index_arrays = [['A','A','B','B','C','C','D','D'],
                range(1,9)]
data = np.random.randint(0,9,size=(8,4))

# 创建多层行索引
multi_row_idx = pd.MultiIndex.from_arrays(index_arrays,
                                          names=['I', 'II'])

# 创建DataFrame
df = pd.DataFrame(data,
                  index=multi_row_idx,
                  columns=['X1','X2','X3','X4'])
df
# Out:
#       X1  X2  X3  X4
# I II
# A 1    8   1   5   7
#   2    6   4   7   0
# B 3    3   7   2   6
#   4    1   2   4   4
# C 5    6   4   5   2
#   6    4   0   3   1
# D 7    7   0   8   6
#   8    6   2   2   1

# %%
multi_row_idx
# Out:
# MultiIndex([('A', 1),
#             ('A', 2),
#             ('B', 3),
#             ('B', 4),
#             ('C', 5),
#             ('C', 6),
#             ('D', 7),
#             ('D', 8)],
#            names=['I', 'II'])

# %%
df.loc[('A', 1):('B',1)]
# Out:
#       X1  X2  X3  X4
# I II
# A 1    8   1   5   7
#   2    6   4   7   0

# %%
df.loc[('A', 1):('C',1)]
# Out:
#       X1  X2  X3  X4
# I II
# A 1    8   1   5   7
#   2    6   4   7   0
# B 3    3   7   2   6
#   4    1   2   4   4

# %%
df.loc[('A', 1):('C',5)]
# Out:
#       X1  X2  X3  X4
# I II
# A 1    8   1   5   7
#   2    6   4   7   0
# B 3    3   7   2   6
#   4    1   2   4   4
# C 5    6   4   5   2

# %%
df.loc[('A', 1)]
# Out:
# X1    1
# X2    3
# X3    3
# X4    5
# Name: (A, 1), dtype: int32

# %%
df.loc[[('A', 1)]]
# Out:
#       X1  X2  X3  X4
# I II
# A 1    8   1   5   7

# %%
df.loc[('A', 1),'X1']
# Out:
# np.int64(8)

# %%
df.loc['A']
# Out:
#     X1  X2  X3  X4
# II
# 1    8   1   5   7
# 2    6   4   7   0

# %%
df.reset_index() # 将行标签转为列标签
# Out:
#    I  II  X1  X2  X3  X4
# 0  A   1   8   1   5   7
# 1  A   2   6   4   7   0
# 2  B   3   3   7   2   6
# 3  B   4   1   2   4   4
# 4  C   5   6   4   5   2
# 5  C   6   4   0   3   1
# 6  D   7   7   0   8   6
# 7  D   8   6   2   2   1

# %%
df.index
# Out:
# MultiIndex([('A', 1),
#             ('A', 2),
#             ('B', 3),
#             ('B', 4),
#             ('C', 5),
#             ('C', 6),
#             ('D', 7),
#             ('D', 8)],
#            names=['I', 'II'])

# %%
list(df.index)
# Out:
# [('A', 1),
#  ('A', 2),
#  ('B', 3),
#  ('B', 4),
#  ('C', 5),
#  ('C', 6),
#  ('D', 7),
#  ('D', 8)]

# %%
# 两组列表
categories = ['A','B','C','D']
types = ['X', 'Y']

# 创建多层行索引
multi_index = pd.MultiIndex.from_product([categories, types], names=['I', 'II'])

# 创建DataFrame
df = pd.DataFrame(data, index=multi_index, columns=['X1','X2','X3','X4'])
df
# Out:
#       X1  X2  X3  X4
# I II
# A X    8   1   5   7
#   Y    6   4   7   0
# B X    3   7   2   6
#   Y    1   2   4   4
# C X    6   4   5   2
#   Y    4   0   3   1
# D X    7   0   8   6
#   Y    6   2   2   1

# %%
df.index = df.index.map('_'.join) # 行标签链接为字符串
df
# Out:
#        X1  X2  X3  X4
# A___X   8   1   5   7
# A___Y   6   4   7   0
# B___X   3   7   2   6
# B___Y   1   2   4   4
# C___X   6   4   5   2
# C___Y   4   0   3   1
# D___X   7   0   8   6
# D___Y   6   2   2   1

# %%
# 创建多层行索引
multi_index = pd.MultiIndex.from_product([types, categories], names=['I', 'II'])

# 创建DataFrame
df = pd.DataFrame(data, index=multi_index, columns=['X1','X2','X3','X4'])
df
# Out:
#       X1  X2  X3  X4
# I II
# X A    8   1   5   7
#   B    6   4   7   0
#   C    3   7   2   6
#   D    1   2   4   4
# Y A    6   4   5   2
#   B    4   0   3   1
#   C    7   0   8   6
#   D    6   2   2   1

# %%
df.index = df.index.map('_'.join)
df
# Out:
#      X1  X2  X3  X4
# X_A   8   1   5   7
# X_B   6   4   7   0
# X_C   3   7   2   6
# X_D   1   2   4   4
# Y_A   6   4   5   2
# Y_B   4   0   3   1
# Y_C   7   0   8   6
# Y_D   6   2   2   1

# %%
data
# Out:
# array([[8, 1, 5, 7],
#        [6, 4, 7, 0],
#        [3, 7, 2, 6],
#        [1, 2, 4, 4],
#        [6, 4, 5, 2],
#        [4, 0, 3, 1],
#        [7, 0, 8, 6],
#        [6, 2, 2, 1]])

# %%
index_tuples = [('A', 'X'), ('A', 'Y'), ('B', 'X'), ('B', 'Y'),('C', 'X'), ('C', 'Y'), ('D', 'X'), ('D', 'Y')]

# 创建多层行索引
multi_index = pd.MultiIndex.from_tuples(index_tuples, names=['I', 'II'])

# 创建DataFrame
df = pd.DataFrame(data, index=multi_index, columns=['X1','X2','X3','X4'])
df
# Out:
#       X1  X2  X3  X4
# I II
# A X    8   1   5   7
#   Y    6   4   7   0
# B X    3   7   2   6
#   Y    1   2   4   4
# C X    6   4   5   2
#   Y    4   0   3   1
# D X    7   0   8   6
#   Y    6   2   2   1

# %%
Index_data = {
    'Category': ['A', 'A', 'B', 'B','C', 'C', 'D', 'D'],
    'Type': ['X', 'Y', 'X', 'Y','X', 'Y', 'X', 'Y']
}
df_index = pd.DataFrame(Index_data)


# 创建多层行索引
multi_index = pd.MultiIndex.from_frame(df_index, names=['I', 'II'])

# 创建DataFrame
df = pd.DataFrame(data, index=multi_index, columns=['X1','X2','X3','X4'])
df
# Out:
#       X1  X2  X3  X4
# I II
# A X    8   1   5   7
#   Y    6   4   7   0
# B X    3   7   2   6
#   Y    1   2   4   4
# C X    6   4   5   2
#   Y    4   0   3   1
# D X    7   0   8   6
#   Y    6   2   2   1

# %% [markdown]
# ### 多层列

# %%
# 创建两层列标签列表
col_arrays = [['A', 'A', 'B', 'B'], ['X1', 'X2', 'X3', 'X4']]
#数据参数不一致col_arrays = [['A','B'], ['X1', 'X2', 'X3', 'X4']] ValueError: all arrays must be same length
# 行索引可以
multi_index = pd.MultiIndex.from_arrays(col_arrays,
                                        names=['I', 'II'])

# 创建DataFrame
df = pd.DataFrame(data, columns=multi_index)
df
# Out:
# I   A     B
# II X1 X2 X3 X4
# 0   8  1  5  7
# 1   6  4  7  0
# 2   3  7  2  6
# 3   1  2  4  4
# 4   6  4  5  2
# 5   4  0  3  1
# 6   7  0  8  6
# 7   6  2  2  1

# %%
df.A
# Out:
# II  X1  X2
# 0    8   1
# 1    6   4
# 2    3   7
# 3    1   2
# 4    6   4
# 5    4   0
# 6    7   0
# 7    6   2

# %%
df.A.X1 # 数据帧
# df.loc[:,'A'].X1
# df.loc[:,('A','X1')]
# df.loc[:,'A'].loc[:,'X1']
# Out:
# 0    8
# 1    6
# 2    3
# 3    1
# 4    6
# 5    4
# 6    7
# 7    6
# Name: X1, dtype: int64

# %%
# Out:
# I   A
# II X1 X2
# 0   1  3
# 1   5  5
# 2   3  5
# 3   5  1
# 4   6  5
# 5   1  1
# 6   6  7
# 7   4  6

# %%
df.loc[:,'A']
# Out:
# II  X1  X2
# 0    1   3
# 1    5   5
# 2    3   5
# 3    5   1
# 4    6   5
# 5    1   1
# 6    6   7
# 7    4   6

# %%
df.loc[:,[('A','X1')]]
# Out:
# I   A
# II X1
# 0   1
# 1   5
# 2   3
# 3   5
# 4   6
# 5   1
# 6   6
# 7   4

# %%
df.loc[:,'A'].loc[:,['X1']]
# Out:
# II  X1
# 0    1
# 1    5
# 2    3
# 3    5
# 4    6
# 5    1
# 6    6
# 7    4

# %%
df.columns
# Out:
# MultiIndex([('A', 'X1'),
#             ('A', 'X2'),
#             ('B', 'X3'),
#             ('B', 'X4')],
#            names=['I', 'II'])

# %%
df.columns = df.columns.map('_'.join)
df
# Out:
#    A_X1  A_X2  B_X3  B_X4
# 0     8     1     5     7
# 1     6     4     7     0
# 2     3     7     2     6
# 3     1     2     4     4
# 4     6     4     5     2
# 5     4     0     3     1
# 6     7     0     8     6
# 7     6     2     2     1

# %%
categories = ['A', 'B']
types = ['X', 'Y']

# 创建多层列索引
multi_index = pd.MultiIndex.from_product([categories, types], names=['I', 'II'])

# 创建DataFrame
df = pd.DataFrame(data, columns=multi_index)
df
# Out:
# I   A     B
# II  X  Y  X  Y
# 0   8  1  5  7
# 1   6  4  7  0
# 2   3  7  2  6
# 3   1  2  4  4
# 4   6  4  5  2
# 5   4  0  3  1
# 6   7  0  8  6
# 7   6  2  2  1

# %%
# 示例数据
index_tuples = [('A', 'X'), ('A', 'Y'), ('B', 'X'), ('B', 'Y')]
# 创建多层列索引
multi_index = pd.MultiIndex.from_tuples(index_tuples, names=['I', 'II'])

# 创建DataFrame
df = pd.DataFrame(data, columns=multi_index)
df
# Out:
# I   A     B
# II  X  Y  X  Y
# 0   8  1  5  7
# 1   6  4  7  0
# 2   3  7  2  6
# 3   1  2  4  4
# 4   6  4  5  2
# 5   4  0  3  1
# 6   7  0  8  6
# 7   6  2  2  1

# %%
dict_index = {
    'Category': ['A', 'A', 'B', 'B'],
    'Type': ['X', 'Y', 'X', 'Y']
}
df_index = pd.DataFrame(dict_index)

# 创建多层列索引
multi_index = pd.MultiIndex.from_frame(df_index, names=['I', 'II'])

# 创建DataFrame
df = pd.DataFrame(data, columns=multi_index)
df
# Out:
# I   A     B
# II  X  Y  X  Y
# 0   8  1  5  7
# 1   6  4  7  0
# 2   3  7  2  6
# 3   1  2  4  4
# 4   6  4  5  2
# 5   4  0  3  1
# 6   7  0  8  6
# 7   6  2  2  1

# %% [markdown]
# ### 多层列、多层行

# %%
index_arrays = [['A','A','B','B','C','C','D','D'],
                range(1,9)]
# 创建多层行索引
multi_row = pd.MultiIndex.from_arrays(index_arrays,
                                          names=['I', 'II'])

# 创建两层列标签列表
col_arrays = [['A', 'A', 'B', 'B'], ['X1', 'X2', 'X3', 'X4']]

# 创建两层列索引
multi_col = pd.MultiIndex.from_arrays(col_arrays,
                                        names=['I', 'II'])

data = np.random.randint(0,9,size=(8,4))



# 创建DataFrame
df = pd.DataFrame(data,
                  index=multi_row,
                  columns=multi_col)
df
# Out:
# I     A     B
# II   X1 X2 X3 X4
# I II
# A 1   1  8  4  6
#   2   4  3  2  6
# B 3   5  8  8  7
#   4   8  1  1  3
# C 5   8  5  1  3
#   6   4  0  1  7
# D 7   1  4  7  3
#   8   1  6  7  6

# %% [markdown]
# # 以下内容移动到第四章，本版块

# %% [markdown]
# ### 鸢尾花数据为例

# %%
iris_df_multi_col = iris_df_original.copy()

index_arrays = [['Quant',  'Quant',  'Quant', 'Quant', 'Categ'],
                ['Sepal',  'Sepal',  'Petal', 'Petal', 'Species'],
                ['Length', 'Width', 'Length', 'Width', 'Species']]

# 创建多层行索引
iris_df_multi_col.columns = pd.MultiIndex.from_arrays(index_arrays, names=['I', 'II', 'III'])
iris_df_multi_col
# Out:
# I    Quant                         Categ
# II   Sepal        Petal          Species
# III Length Width Length Width    Species
# 0      5.1   3.5    1.4   0.2     setosa
# 1      4.9   3.0    1.4   0.2     setosa
# 2      4.7   3.2    1.3   0.2     setosa
# 3      4.6   3.1    1.5   0.2     setosa
# 4      5.0   3.6    1.4   0.2     setosa
# ..     ...   ...    ...   ...        ...
# 145    6.7   3.0    5.2   2.3  virginica
# 146    6.3   2.5    5.0   1.9  virginica
# 147    6.5   3.0    5.2   2.0  virginica
# 148    6.2   3.4    5.4   2.3  virginica
# 149    5.9   3.0    5.1   1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris_df_multi_col.columns
# Out:
# MultiIndex([('Quant',   'Sepal',  'Length'),
#             ('Quant',   'Sepal',   'Width'),
#             ('Quant',   'Petal',  'Length'),
#             ('Quant',   'Petal',   'Width'),
#             ('Categ', 'Species', 'Species')],
#            names=['I', 'II', 'III'])

# %%
iris_df_multi_col.loc[:,'Categ']
# Out:
# II     Species
# III    Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 1 columns]

# %%
iris_df_multi_col.xs('Sepal', level='II', axis=1)
# Out:
# I    Quant
# III Length Width
# 0      5.1   3.5
# 1      4.9   3.0
# 2      4.7   3.2
# 3      4.6   3.1
# 4      5.0   3.6
# ..     ...   ...
# 145    6.7   3.0
# 146    6.3   2.5
# 147    6.5   3.0
# 148    6.2   3.4
# 149    5.9   3.0
#
# [150 rows x 2 columns]

# %%
iris_df_multi_col[;,;]
# Out:
#   File "/tmp/ipykernel_581/3896824641.py", line 1
#     iris_df_multi_col[;,;]
#                       ^
# SyntaxError: invalid syntax

# %%
df.loc[2, ('Quant', 'Sepal', 'Length')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_581/2610778263.py in <cell line: 0>()
# ----> 1 df.loc[2, ('Quant', 'Sepal', 'Length')]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1182             if self._is_scalar_access(key):
#    1183                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184             return self._getitem_tuple(key)
#    1185         else:
#    1186             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1366         with suppress(IndexingError):
#    1367             tup = self._expand_ellipsis(tup)
# -> 1368             return self._getitem_lowerdim(tup)
#    1369
#    1370         # no multi-index, so validate all of the indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#    1039         # we may have a nested tuples indexer here
#    1040         if self._is_nested_tuple_indexer(tup):
# -> 1041             return self._getitem_nested_tuple(tup)
#    1042
#    1043         # we maybe be using a tuple to represent multiple dimensions here
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_nested_tuple(self, tup)
#    1151                 continue
#    1152
# -> 1153             obj = getattr(obj, self.name)._getitem_axis(key, axis=axis)
#    1154             axis -= 1
#    1155
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1429         # fall thru to straight lookup
#    1430         self._validate_key(key, axis)
# -> 1431         return self._get_label(key, axis=axis)
#    1432
#    1433     def _get_slice_axis(self, slice_obj: slice, axis: AxisInt):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1379     def _get_label(self, label, axis: AxisInt):
#    1380         # GH#5567 this will fail if the label is not present in the axis.
# -> 1381         return self.obj.xs(label, axis=axis)
#    1382
#    1383     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    4285         if axis == 1:
#    4286             if drop_level:
# -> 4287                 return self[key]
#    4288             index = self.columns
#    4289         else:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4099         if is_single_key:
#    4100             if self.columns.nlevels > 1:
# -> 4101                 return self._getitem_multilevel(key)
#    4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _getitem_multilevel(self, key)
#    4157     def _getitem_multilevel(self, key):
#    4158         # self.columns is a MultiIndex
# -> 4159         loc = self.columns.get_loc(key)
#    4160         if isinstance(loc, (slice, np.ndarray)):
#    4161             new_columns = self.columns[loc]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/multi.py in get_loc(self, key)
#    3043         keylen = len(key)
#    3044         if self.nlevels < keylen:
# -> 3045             raise KeyError(
#    3046                 f"Key length ({keylen}) exceeds index depth ({self.nlevels})"
#    3047             )
#
# KeyError: 'Key length (3) exceeds index depth (2)'

# %%
iris_df_multi_col.loc[:,('Sepal','Length')]
# Out:
# /tmp/ipykernel_581/2091534152.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   iris_df_multi_col.loc[:,('Sepal','Length')]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sepal'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_581/2091534152.py in <cell line: 0>()
# ----> 1 iris_df_multi_col.loc[:,('Sepal','Length')]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1182             if self._is_scalar_access(key):
#    1183                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184             return self._getitem_tuple(key)
#    1185         else:
#    1186             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1366         with suppress(IndexingError):
#    1367             tup = self._expand_ellipsis(tup)
# -> 1368             return self._getitem_lowerdim(tup)
#    1369
#    1370         # no multi-index, so validate all of the indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#    1039         # we may have a nested tuples indexer here
#    1040         if self._is_nested_tuple_indexer(tup):
# -> 1041             return self._getitem_nested_tuple(tup)
#    1042
#    1043         # we maybe be using a tuple to represent multiple dimensions here
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_nested_tuple(self, tup)
#    1151                 continue
#    1152
# -> 1153             obj = getattr(obj, self.name)._getitem_axis(key, axis=axis)
#    1154             axis -= 1
#    1155
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1429         # fall thru to straight lookup
#    1430         self._validate_key(key, axis)
# -> 1431         return self._get_label(key, axis=axis)
#    1432
#    1433     def _get_slice_axis(self, slice_obj: slice, axis: AxisInt):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1379     def _get_label(self, label, axis: AxisInt):
#    1380         # GH#5567 this will fail if the label is not present in the axis.
# -> 1381         return self.obj.xs(label, axis=axis)
#    1382
#    1383     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    4285         if axis == 1:
#    4286             if drop_level:
# -> 4287                 return self[key]
#    4288             index = self.columns
#    4289         else:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4099         if is_single_key:
#    4100             if self.columns.nlevels > 1:
# -> 4101                 return self._getitem_multilevel(key)
#    4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _getitem_multilevel(self, key)
#    4157     def _getitem_multilevel(self, key):
#    4158         # self.columns is a MultiIndex
# -> 4159         loc = self.columns.get_loc(key)
#    4160         if isinstance(loc, (slice, np.ndarray)):
#    4161             new_columns = self.columns[loc]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/multi.py in get_loc(self, key)
#    3092
#    3093         for i, k in enumerate(follow_key, len(lead_key)):
# -> 3094             mask = self.codes[i][loc] == self._get_loc_single_level_index(
#    3095                 self.levels[i], k
#    3096             )
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/multi.py in _get_loc_single_level_index(self, level_index, key)
#    2978             return -1
#    2979         else:
# -> 2980             return level_index.get_loc(key)
#    2981
#    2982     def get_loc(self, key):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Sepal'

# %%
iris_df_multi_row = iris_df_original.reset_index()

# 定义函数将花萼长度映射为等级
def map_sepal_length_to_category(sepal_length):
    if sepal_length < 5:
        return 'D'
    elif 5 <= sepal_length < 6:
        return 'C'
    elif 6 <= sepal_length < 7:
        return 'B'
    else:
        return 'A'

# 使用 apply 函数将 sepal_length 映射为等级并添加新列
iris_df_multi_row['category'] = iris_df_multi_row['sepal_length'].apply(map_sepal_length_to_category)

# %%
iris_df_multi_row
# Out:
#      index  sepal_length  sepal_width  petal_length  petal_width    species  \
# 0        0           5.1          3.5           1.4          0.2     setosa
# 1        1           4.9          3.0           1.4          0.2     setosa
# 2        2           4.7          3.2           1.3          0.2     setosa
# 3        3           4.6          3.1           1.5          0.2     setosa
# 4        4           5.0          3.6           1.4          0.2     setosa
# ..     ...           ...          ...           ...          ...        ...
# 145    145           6.7          3.0           5.2          2.3  virginica
# 146    146           6.3          2.5           5.0          1.9  virginica
# 147    147           6.5          3.0           5.2          2.0  virginica
# 148    148           6.2          3.4           5.4          2.3  virginica
# 149    149           5.9          3.0           5.1          1.8  virginica
#
#     category
# 0          C
# 1          D
# 2          D
# 3          D
# 4          C
# ..       ...
# 145        B
# 146        B
# 147        B
# 148        B
# 149        C
#
# [150 rows x 7 columns]

# %%
# 以 'species' 列为第一级索引，'category'为二级索引，'index' 列（之前的索引）为第三级索引
iris_df_multi_row.set_index(['species', 'category','index']) # , inplace=True
# Out:
#                           sepal_length  sepal_width  petal_length  petal_width
# species   category index
# setosa    C        0               5.1          3.5           1.4          0.2
#           D        1               4.9          3.0           1.4          0.2
#                    2               4.7          3.2           1.3          0.2
#                    3               4.6          3.1           1.5          0.2
#           C        4               5.0          3.6           1.4          0.2
# ...                                ...          ...           ...          ...
# virginica B        145             6.7          3.0           5.2          2.3
#                    146             6.3          2.5           5.0          1.9
#                    147             6.5          3.0           5.2          2.0
#                    148             6.2          3.4           5.4          2.3
#           C        149             5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df = iris_df_multi_row.sort_values(by=['category', 'species']).set_index(['category', 'species', 'index']) # , inplace=True
df
# Out:
#                            sepal_length  sepal_width  petal_length  \
# category species    index
# A        versicolor 50              7.0          3.2           4.7
#          virginica  102             7.1          3.0           5.9
#                     105             7.6          3.0           6.6
#                     107             7.3          2.9           6.3
#                     109             7.2          3.6           6.1
# ...                                 ...          ...           ...
# D        setosa     42              4.4          3.2           1.3
#                     45              4.8          3.0           1.4
#                     47              4.6          3.2           1.4
#          versicolor 57              4.9          2.4           3.3
#          virginica  106             4.9          2.5           4.5
#
#                            petal_width
# category species    index
# A        versicolor 50             1.4
#          virginica  102            2.1
#                     105            2.1
#                     107            1.8
#                     109            2.5
# ...                                ...
# D        setosa     42             0.2
#                     45             0.3
#                     47             0.2
#          versicolor 57             1.0
#          virginica  106            1.7
#
# [150 rows x 4 columns]

# %%
df.reset_index() # 将行索引转为列索引
# Out:
#     category     species  index  sepal_length  sepal_width  petal_length  \
# 0          A  versicolor     50           7.0          3.2           4.7
# 1          A   virginica    102           7.1          3.0           5.9
# 2          A   virginica    105           7.6          3.0           6.6
# 3          A   virginica    107           7.3          2.9           6.3
# 4          A   virginica    109           7.2          3.6           6.1
# ..       ...         ...    ...           ...          ...           ...
# 145        D      setosa     42           4.4          3.2           1.3
# 146        D      setosa     45           4.8          3.0           1.4
# 147        D      setosa     47           4.6          3.2           1.4
# 148        D  versicolor     57           4.9          2.4           3.3
# 149        D   virginica    106           4.9          2.5           4.5
#
#      petal_width
# 0            1.4
# 1            2.1
# 2            2.1
# 3            1.8
# 4            2.5
# ..           ...
# 145          0.2
# 146          0.3
# 147          0.2
# 148          1.0
# 149          1.7
#
# [150 rows x 7 columns]

# %%
df.index
# Out:
# MultiIndex([('A', 'versicolor',  50),
#             ('A',  'virginica', 102),
#             ('A',  'virginica', 105),
#             ('A',  'virginica', 107),
#             ('A',  'virginica', 109),
#             ('A',  'virginica', 117),
#             ('A',  'virginica', 118),
#             ('A',  'virginica', 122),
#             ('A',  'virginica', 125),
#             ('A',  'virginica', 129),
#             ...
#             ('D',     'setosa',  30),
#             ('D',     'setosa',  34),
#             ('D',     'setosa',  37),
#             ('D',     'setosa',  38),
#             ('D',     'setosa',  41),
#             ('D',     'setosa',  42),
#             ('D',     'setosa',  45),
#             ('D',     'setosa',  47),
#             ('D', 'versicolor',  57),
#             ('D',  'virginica', 106)],
#            names=['category', 'species', 'index'], length=150)

# %%
df.loc[('A', 'versicolor',  50)]
# Out:
# sepal_length    7.0
# sepal_width     3.2
# petal_length    4.7
# petal_width     1.4
# Name: (A, versicolor, 50), dtype: float64

# %%
df.loc[('A', 'versicolor',  50):('A',  'virginica', 129)]
# Out:
#                            sepal_length  sepal_width  petal_length  \
# category species    index
# A        versicolor 50              7.0          3.2           4.7
#          virginica  102             7.1          3.0           5.9
#                     105             7.6          3.0           6.6
#                     107             7.3          2.9           6.3
#                     109             7.2          3.6           6.1
#                     117             7.7          3.8           6.7
#                     118             7.7          2.6           6.9
#                     122             7.7          2.8           6.7
#                     125             7.2          3.2           6.0
#                     129             7.2          3.0           5.8
#
#                            petal_width
# category species    index
# A        versicolor 50             1.4
#          virginica  102            2.1
#                     105            2.1
#                     107            1.8
#                     109            2.5
#                     117            2.2
#                     118            2.3
#                     122            2.0
#                     125            1.8
#                     129            1.6

# %%
df.loc['A']
# Out:
#                   sepal_length  sepal_width  petal_length  petal_width
# species    index
# versicolor 50              7.0          3.2           4.7          1.4
# virginica  102             7.1          3.0           5.9          2.1
#            105             7.6          3.0           6.6          2.1
#            107             7.3          2.9           6.3          1.8
#            109             7.2          3.6           6.1          2.5
#            117             7.7          3.8           6.7          2.2
#            118             7.7          2.6           6.9          2.3
#            122             7.7          2.8           6.7          2.0
#            125             7.2          3.2           6.0          1.8
#            129             7.2          3.0           5.8          1.6
#            130             7.4          2.8           6.1          1.9
#            131             7.9          3.8           6.4          2.0
#            135             7.7          3.0           6.1          2.3

# %%
df.loc['A'].loc['virginica']
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# index
# 102             7.1          3.0           5.9          2.1
# 105             7.6          3.0           6.6          2.1
# 107             7.3          2.9           6.3          1.8
# 109             7.2          3.6           6.1          2.5
# 117             7.7          3.8           6.7          2.2
# 118             7.7          2.6           6.9          2.3
# 122             7.7          2.8           6.7          2.0
# 125             7.2          3.2           6.0          1.8
# 129             7.2          3.0           5.8          1.6
# 130             7.4          2.8           6.1          1.9
# 131             7.9          3.8           6.4          2.0
# 135             7.7          3.0           6.1          2.3

# %% [markdown]
# ## 时间序列indexing

# %%
# 安装pandas_datareader
! pip install pandas_datareader
# Out:
# Requirement already satisfied: pandas_datareader in /usr/local/lib/python3.12/dist-packages (0.11.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from pandas_datareader) (6.1.1)
# Requirement already satisfied: pandas>=2.1.4 in /usr/local/lib/python3.12/dist-packages (from pandas_datareader) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pandas_datareader) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from pandas_datareader) (75.2.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1.4->pandas_datareader) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1.4->pandas_datareader) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1.4->pandas_datareader) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1.4->pandas_datareader) (2026.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pandas_datareader) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pandas_datareader) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pandas_datareader) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pandas_datareader) (2026.6.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.1.4->pandas_datareader) (1.17.0)

# %% [markdown]
# ### 创建时间序列

# %%
import pandas_datareader as pdr
import datetime

start_date = datetime.datetime(2020, 1, 1)
end_date   = datetime.datetime(2022, 12, 31)

ticker_list = ['SP500']
SP500_df = pdr.DataReader(ticker_list,
                    'fred',
                    start_date,
                    end_date)
SP500_df
# Out:
#               SP500
# DATE
# 2020-01-01      NaN
# 2020-01-02  3257.85
# 2020-01-03  3234.85
# 2020-01-06  3246.28
# 2020-01-07  3237.18
# ...             ...
# 2022-12-26      NaN
# 2022-12-27  3829.25
# 2022-12-28  3783.22
# 2022-12-29  3849.28
# 2022-12-30  3839.50
#
# [783 rows x 1 columns]

# %%
SP500_df.loc['2022-06-01':]
# Out:
#               SP500
# DATE
# 2022-06-01  4101.23
# 2022-06-02  4176.82
# 2022-06-03  4108.54
# 2022-06-06  4121.43
# 2022-06-07  4160.68
# ...             ...
# 2022-12-26      NaN
# 2022-12-27  3829.25
# 2022-12-28  3783.22
# 2022-12-29  3849.28
# 2022-12-30  3839.50
#
# [153 rows x 1 columns]

# %%
SP500_df.query("DATE.dt.year > 2021")
# Out:
#               SP500
# DATE
# 2022-01-03  4796.56
# 2022-01-04  4793.54
# 2022-01-05  4700.58
# 2022-01-06  4696.05
# 2022-01-07  4677.03
# ...             ...
# 2022-12-26      NaN
# 2022-12-27  3829.25
# 2022-12-28  3783.22
# 2022-12-29  3849.28
# 2022-12-30  3839.50
#
# [260 rows x 1 columns]

# %%
# Repo: https://github.com/Visualize-ML
# Book 1 Python for Beginners  |  From Basic Arithmetic to Machine Learning
# Published and copyrighted by Tsinghua University Press
# Beijing, China, 2023
